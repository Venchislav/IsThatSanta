# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# # **DATA PREPROCESSING**
# 1. Data reading
# 2. Data augmentation
# 3. Dataset splitting

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
"""train_gen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_gen = ImageDataGenerator(
    rescale=1.0 / 255
)"""
# Out:
# 'train_gen = ImageDataGenerator(\n        rescale=1./255,\n        shear_range=0.2,\n        zoom_range=0.2,\n        horizontal_flip=True)\n\ntest_gen = ImageDataGenerator(\n    rescale=1.0 / 255\n)'

# %%
ds_train = image_dataset_from_directory('train', batch_size=64)
ds_test = image_dataset_from_directory(
    'test',
)
# Out:
# Found 614 files belonging to 2 classes.
# Found 612 files belonging to 2 classes.

# %%
type(ds_train)
# Out:
# tensorflow.python.data.ops.prefetch_op._PrefetchDataset

# %%
def resize_rescale(im, lbl):
    return tf.image.resize(im, (224, 224)) / 255.0, lbl

# %%
ds_train = ds_train.map(resize_rescale)
ds_test = ds_test.map(resize_rescale)

# %%
import matplotlib.pyplot as plt

# %%
def visualize_diff(image, augmented_img):
  plt.subplot(1, 2, 1)
  plt.title('Original Image: ')
  plt.imshow(image);

  plt.subplot(1, 2, 2)
  plt.title('Augmented Image: ')
  plt.imshow(augmented_img);

# %%
img_ = list(ds_train.take(1))[0][0][0]
augmented_img = tf.image.rot90(img_)

# %%
visualize_diff(img_, augmented_img)

# %%
for img, lbl in ds_train.take(1):
    print(lbl[0])
    plt.imshow(img[0])
    break
# Out:
# tf.Tensor(0, shape=(), dtype=int32)

# %%
# 1 - santa
# 0 - not santa

# %%
from tensorflow.keras import layers

# %%
data_augmentation = tf.keras.Sequential([
  layers.InputLayer(input_shape=(224, 224, 3)),
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(0.5, 0.2)
])

# %%
model = tf.keras.Sequential([
  data_augmentation,
  layers.Conv2D(10, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Conv2D(15, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Conv2D(30, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),

  layers.Dense(256, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(64, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(2, activation='sigmoid'),
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics='accuracy'
)

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='weights',
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
hist = model.fit(
    ds_train,
    validation_data=ds_test,
    epochs=25,
    verbose=2,
    shuffle=True,
    callbacks=[cp_callback]
)
# Out:
# Epoch 1/25
# Epoch 1: saving model to weights
# 10/10 - 8s - loss: 1.2622 - accuracy: 0.5049 - val_loss: 0.6913 - val_accuracy: 0.5212 - 8s/epoch - 786ms/step
# Epoch 2/25
#
# Epoch 2: saving model to weights
# 10/10 - 6s - loss: 0.7257 - accuracy: 0.5033 - val_loss: 0.6893 - val_accuracy: 0.6422 - 6s/epoch - 649ms/step
# Epoch 3/25
#
# Epoch 3: saving model to weights
# 10/10 - 7s - loss: 0.6759 - accuracy: 0.5098 - val_loss: 0.6881 - val_accuracy: 0.5801 - 7s/epoch - 652ms/step
# Epoch 4/25
#
# Epoch 4: saving model to weights
# 10/10 - 6s - loss: 0.6470 - accuracy: 0.5912 - val_loss: 0.6991 - val_accuracy: 0.5131 - 6s/epoch - 643ms/step
# Epoch 5/25
#
# Epoch 5: saving model to weights
# 10/10 - 7s - loss: 0.5408 - accuracy: 0.7508 - val_loss: 0.6761 - val_accuracy: 0.5833 - 7s/epoch - 675ms/step
# Epoch 6/25
#
# Epoch 6: saving model to weights
# 10/10 - 7s - loss: 0.4599 - accuracy: 0.7915 - val_loss: 0.7663 - val_accuracy: 0.5703 - 7s/epoch - 656ms/step
# Epoch 7/25
#
# Epoch 7: saving model to weights
# 10/10 - 6s - loss: 0.4129 - accuracy: 0.8306 - val_loss: 0.6574 - val_accuracy: 0.6356 - 6s/epoch - 637ms/step
# Epoch 8/25
#
# Epoch 8: saving model to weights
# 10/10 - 7s - loss: 0.3451 - accuracy: 0.8632 - val_loss: 0.6710 - val_accuracy: 0.6716 - 7s/epoch - 654ms/step
# Epoch 9/25
#
# Epoch 9: saving model to weights
# 10/10 - 7s - loss: 0.3247 - accuracy: 0.8681 - val_loss: 0.5923 - val_accuracy: 0.7320 - 7s/epoch - 650ms/step
# Epoch 10/25
#
# Epoch 10: saving model to weights
# 10/10 - 7s - loss: 0.2930 - accuracy: 0.9007 - val_loss: 0.6922 - val_accuracy: 0.7157 - 7s/epoch - 684ms/step
# Epoch 11/25
#
# Epoch 11: saving model to weights
# 10/10 - 6s - loss: 0.2881 - accuracy: 0.8844 - val_loss: 0.6105 - val_accuracy: 0.7598 - 6s/epoch - 643ms/step
# Epoch 12/25
#
# Epoch 12: saving model to weights
# 10/10 - 7s - loss: 0.2754 - accuracy: 0.8925 - val_loss: 0.6275 - val_accuracy: 0.7680 - 7s/epoch - 652ms/step
# Epoch 13/25
#
# Epoch 13: saving model to weights
# 10/10 - 6s - loss: 0.2490 - accuracy: 0.8990 - val_loss: 0.7431 - val_accuracy: 0.7369 - 6s/epoch - 644ms/step
# Epoch 14/25
#
# Epoch 14: saving model to weights
# 10/10 - 7s - loss: 0.2894 - accuracy: 0.8876 - val_loss: 0.8005 - val_accuracy: 0.7255 - 7s/epoch - 651ms/step
# Epoch 15/25
#
# Epoch 15: saving model to weights
# 10/10 - 7s - loss: 0.3518 - accuracy: 0.8469 - val_loss: 0.5008 - val_accuracy: 0.7974 - 7s/epoch - 679ms/step
# Epoch 16/25
#
# Epoch 16: saving model to weights
# 10/10 - 6s - loss: 0.2805 - accuracy: 0.8909 - val_loss: 0.4516 - val_accuracy: 0.8121 - 6s/epoch - 643ms/step
# Epoch 17/25
#
# Epoch 17: saving model to weights
# 10/10 - 6s - loss: 0.2707 - accuracy: 0.8941 - val_loss: 0.4775 - val_accuracy: 0.8105 - 6s/epoch - 650ms/step
# Epoch 18/25
#
# Epoch 18: saving model to weights
# 10/10 - 7s - loss: 0.2801 - accuracy: 0.8958 - val_loss: 0.5809 - val_accuracy: 0.7810 - 7s/epoch - 654ms/step
# Epoch 19/25
#
# Epoch 19: saving model to weights
# 10/10 - 6s - loss: 0.2473 - accuracy: 0.9137 - val_loss: 0.5109 - val_accuracy: 0.8088 - 6s/epoch - 642ms/step
# Epoch 20/25
#
# Epoch 20: saving model to weights
# 10/10 - 7s - loss: 0.2339 - accuracy: 0.9055 - val_loss: 0.5460 - val_accuracy: 0.8088 - 7s/epoch - 672ms/step
# Epoch 21/25
#
# Epoch 21: saving model to weights
# 10/10 - 7s - loss: 0.2610 - accuracy: 0.9055 - val_loss: 0.5654 - val_accuracy: 0.8056 - 7s/epoch - 654ms/step
# Epoch 22/25
#
# Epoch 22: saving model to weights
# 10/10 - 6s - loss: 0.2728 - accuracy: 0.8941 - val_loss: 0.4413 - val_accuracy: 0.8350 - 6s/epoch - 641ms/step
# Epoch 23/25
#
# Epoch 23: saving model to weights
# 10/10 - 6s - loss: 0.2457 - accuracy: 0.8958 - val_loss: 0.4624 - val_accuracy: 0.8382 - 6s/epoch - 648ms/step
# Epoch 24/25
#
# Epoch 24: saving model to weights
# 10/10 - 7s - loss: 0.2238 - accuracy: 0.9186 - val_loss: 0.4903 - val_accuracy: 0.8350 - 7s/epoch - 653ms/step
# Epoch 25/25
#
# Epoch 25: saving model to weights
# 10/10 - 7s - loss: 0.2330 - accuracy: 0.9121 - val_loss: 0.5050 - val_accuracy: 0.8284 - 7s/epoch - 663ms/step

# %%
from pathlib import Path
import imghdr

data_dir = "test"
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")

# %%
model.evaluate(ds_test)
# Out:
# 20/20 [==============================] - 2s 52ms/step - loss: 0.5050 - accuracy: 0.8284
# [0.5049827694892883, 0.8284313678741455]

# %%
y_pred = model.predict(ds_test)
# Out:
# 20/20 [==============================] - 2s 53ms/step

# %%
# FINALLY, MODEL WORKS WELL !!!!

# %%
def create_model():
    model = tf.keras.Sequential([
        data_augmentation,
        layers.Conv2D(10, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Dropout(0.2),
        layers.Conv2D(15, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Dropout(0.2),
        layers.Conv2D(30, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Dropout(0.2),
        layers.Flatten(),

        layers.Dense(256, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(2, activation='sigmoid'),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics='accuracy'
    )

    return model

# %%
model = create_model()

# %%
model.evaluate(ds_test)
# Out:
# 20/20 [==============================] - 2s 53ms/step - loss: 0.7100 - accuracy: 0.4722
# [0.7099581360816956, 0.4722222089767456]

# %%
model.load_weights('weights')

# %%
model.evaluate(ds_test)
# Out:
# 20/20 [==============================] - 2s 53ms/step - loss: 0.5050 - accuracy: 0.8284
# [0.5049827694892883, 0.8284313678741455]

# %%
# Now we don't need to fit our model!!!
# And I can start creating a app!!!
# Next level

# %% [markdown]
# # **PREDICTION**

# %%
def show_pred(pred):
    return 'Santa' if pred == 1 else 'Not Santa'

# %%
def add_understanding(perc):
    return "So it's not santa" if perc < 50 else "So it's most likely santa"

# %%
def pred(im_path):
    img = tf.keras.utils.load_img(im_path)
    img = tf.keras.utils.img_to_array(img)
    img = tf.image.resize(img, (224, 224))
    img = img / 255.0
    img = tf.reshape(img, (1, 224, 224, 3))
    plt.title(show_pred(np.argmax(model.predict(img))))
    plt.axis('off')
    plt.imshow(img[0]);
    return f"Model is {model.predict(img)[0][1] * 100}% sure it's santa {add_understanding(model.predict(img)[0][1] * 100)}. Happy new Year!"

# %%
pred('TEST_IMAGE.jpg')
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# "Model is 56.537097692489624% sure it's santa So it's most likely santa. Happy new Year!"

# %%
pred('NOT_SANTA_TEST.jpg')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# "Model is 23.165595531463623% sure it's santa So it's not santa. Happy new Year!"

# %%
import cv2

cam = cv2.VideoCapture(0)

cv2.namedWindow("test")

img_counter = 0

while True:
    ret, frame = cam.read()
    if not ret:
        print("failed to grab frame")
        break
    cv2.imshow("test", frame)

    k = cv2.waitKey(1)
    if k % 256 == 27:
        # ESC pressed
        print("Escape hit, closing...")
        break
    elif k % 256 == 32:
        # SPACE pressed
        img_name = "Images_taken\opencv_frame_{}.png".format(img_counter)
        cv2.imwrite(img_name, frame)
        print("{} written!".format(img_name))
        img_counter += 1

cam.release()

cv2.destroyAllWindows()
pred(img_name)
# Out:
# Images_taken\opencv_frame_0.png written!
# Escape hit, closing...
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# "Model is 20.747920870780945% sure it's santa So it's not santa. Happy new Year!"

# %% [markdown]
# # **FINALLY... I KNOW THAT MY CACTUS IS NOT A SANTA**
